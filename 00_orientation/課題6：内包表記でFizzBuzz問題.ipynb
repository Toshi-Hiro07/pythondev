# %%
#内包しないやつ　fizzbuzz_list = []  

#for i in range(1, 101):
    #if i % 3 == 0 and i % 5 == 0:
        #fizzbuzz_list.append("FizzBuzz")
    #elif i % 3 == 0:
        #fizzbuzz_list.append("Fizz")
    #elif i % 5 == 0:
        #fizzbuzz_list.append("Buzz")
    #else:
        #fizzbuzz_list.append(str(i))

#print(fizzbuzz_list)
fizzbuzz_list = [
    "FizzBuzz" if i % 3 == 0 and i % 5 == 0
    else "Fizz" if i % 3 == 0
    else "Buzz" if i % 5 == 0
    else str(i)
    for i in range(1, 101)
]

print(fizzbuzz_list)
