# %%
fee = int(input("値段を入力してください"))
if fee>=2000:
    print("送料は無料です")
    fee=fee*1.1
    fee=int(fee)
    print("送料込みの価格は"+str(fee)+"です。")
if fee<2000:
    fee=fee*1.1+350
    fee=int(fee)
    print("送料として350円かかります")
    print("送料込みの価格は"+str(fee)+"です。")
# Out:
# 送料は無料です
# 送料込みの価格は2200です。
